# %% [markdown]
# ## Read and Parse CO2 Data
#
# read in CO2 Emissions data
# --> dictionary {year:{data}}

# %%
with open('CO2-emissions.txt', 'r') as f:
    co2_list = []
    full = f.readlines()
    for line in full:
        if len(line) > 1 or line != '\n':
            x = line.strip().split()
            co2_list.append(x)
co2_list
# Out:
# [['Year',
#   'Total',
#   'Gas',
#   'Liquids',
#   'Solids',
#   'Cement_Production',
#   'Gas_Flaring',
#   'Per_Capita'],
#  ['1751', '3', '0', '0', '3', '0', '0'],
#  ['1752', '3', '0', '0', '3', '0', '0'],
#  ['1753', '3', '0', '0', '3', '0', '0'],
#  ['1754', '3', '0', '0', '3', '0', '0'],
#  ['1755', '3', '0', '0', '3', '0', '0'],
#  ['1756', '3', '0', '0', '3', '0', '0'],
#  ['1757', '3', '0', '0', '3', '0', '0'],
#  ['1758', '3', '0', '0', '3', '0', '0'],
#  ['1759', '3', '0', '0', '3', '0', '0'],
#  ['1760', '3', '0', '0', '3', '0', '0'],
#  ['1761', '3', '0', '0', '3', '0', '0'],
#  ['1762', '3', '0', '0', '3', '0', '0'],
#  ['1763', '3', '0', '0', '3', '0', '0'],
#  ['1764', '3', '0', '0', '3', '0', '0'],
#  ['1765', '3', '0', '0', '3', '0', '0'],
#  ['1766', '3', '0', '0', '3', '0', '0'],
#  ['1767', '3', '0', '0', '3', '0', '0'],
#  ['1768', '3', '0', '0', '3', '0', '0'],
#  ['1769', '3', '0', '0', '3', '0', '0'],
#  ['1770', '3', '0', '0', '3', '0', '0'],
#  ['1771', '4', '0', '0', '4', '0', '0'],
#  ['1772', '4', '0', '0', '4', '0', '0'],
#  ['1773', '4', '0', '0', '4', '0', '0'],
#  ['1774', '4', '0', '0', '4', '0', '0'],
#  ['1775', '4', '0', '0', '4', '0', '0'],
#  ['1776', '4', '0', '0', '4', '0', '0'],
#  ['1777', '4', '0', '0', '4', '0', '0'],
#  ['1778', '4', '0', '0', '4', '0', '0'],
#  ['1779', '4', '0', '0', '4', '0', '0'],
#  ['1780', '4', '0', '0', '4', '0', '0'],
#  ['1781', '5', '0', '0', '5', '0', '0'],
#  ['1782', '5', '0', '0', '5', '0', '0'],
#  ['1783', '5', '0', '0', '5', '0', '0'],
#  ['1784', '5', '0', '0', '5', '0', '0'],
#  ['1785', '5', '0', '0', '5', '0', '0'],
#  ['1786', '5', '0', '0', '5', '0', '0'],
#  ['1787', '5', '0', '0', '5', '0', '0'],
#  ['1788', '5', '0', '0', '5', '0', '0'],
#  ['1789', '5', '0', '0', '5', '0', '0'],
#  ['1790', '5', '0', '0', '5', '0', '0'],
#  ['1791', '6', '0', '0', '6', '0', '0'],
#  ['1792', '6', '0', '0', '6', '0', '0'],
#  ['1793', '6', '0', '0', '6', '0', '0'],
#  ['1794', '6', '0', '0', '6', '0', '0'],
#  ['1795', '6', '0', '0', '6', '0', '0'],
#  ['1796', '6', '0', '0', '6', '0', '0'],
#  ['1797', '7', '0', '0', '7', '0', '0'],
#  ['1798', '7', '0', '0', '7', '0', '0'],
#  ['1799', '7', '0', '0', '7', '0', '0'],
#  ['1800', '8', '0', '0', '8', '0', '0'],
#  ['1801', '8', '0', '0', '8', '0', '0'],
#  ['1802', '10', '0', '0', '10', '0', '0'],
#  ['1803', '9', '0', '0', '9', '0', '0'],
#  ['1804', '9', '0', '0', '9', '0', '0'],
#  ['1805', '9', '0', '0', '9', '0', '0'],
#  ['1806', '10', '0', '0', '10', '0', '0'],
#  ['1807', '10', '0', '0', '10', '0', '0'],
#  ['1808', '10', '0', '0', '10', '0', '0'],
#  ['1809', '10', '0', '0', '10', '0', '0'],
#  ['1810', '10', '0', '0', '10', '0', '0'],
#  ['1811', '11', '0', '0', '11', '0', '0'],
#  ['1812', '11', '0', '0', '11', '0', '0'],
#  ['1813', '11', '0', '0', '11', '0', '0'],
#  ['1814', '11', '0', '0', '11', '0', '0'],
#  ['1815', '12', '0', '0', '12', '0', '0'],
#  ['1816', '13', '0', '0', '13', '0', '0'],
#  ['1817', '14', '0', '0', '14', '0', '0'],
#  ['1818', '14', '0', '0', '14', '0', '0'],
#  ['1819', '14', '0', '0', '14', '0', '0'],
#  ['1820', '14', '0', '0', '14', '0', '0'],
#  ['1821', '14', '0', '0', '14', '0', '0'],
#  ['1822', '15', '0', '0', '15', '0', '0'],
#  ['1823', '16', '0', '0', '16', '0', '0'],
#  ['1824', '16', '0', '0', '16', '0', '0'],
#  ['1825', '17', '0', '0', '17', '0', '0'],
#  ['1826', '17', '0', '0', '17', '0', '0'],
#  ['1827', '18', '0', '0', '18', '0', '0'],
#  ['1828', '18', '0', '0', '18', '0', '0'],
#  ['1829', '18', '0', '0', '18', '0', '0'],
#  ['1830', '24', '0', '0', '24', '0', '0'],
#  ['1831', '23', '0', '0', '23', '0', '0'],
#  ['1832', '23', '0', '0', '23', '0', '0'],
#  ['1833', '24', '0', '0', '24', '0', '0'],
#  ['1834', '24', '0', '0', '24', '0', '0'],
#  ['1835', '25', '0', '0', '25', '0', '0'],
#  ['1836', '29', '0', '0', '29', '0', '0'],
#  ['1837', '29', '0', '0', '29', '0', '0'],
#  ['1838', '30', '0', '0', '30', '0', '0'],
#  ['1839', '31', '0', '0', '31', '0', '0'],
#  ['1840', '33', '0', '0', '33', '0', '0'],
#  ['1841', '34', '0', '0', '34', '0', '0'],
#  ['1842', '36', '0', '0', '36', '0', '0'],
#  ['1843', '37', '0', '0', '37', '0', '0'],
#  ['1844', '39', '0', '0', '39', '0', '0'],
#  ['1845', '43', '0', '0', '43', '0', '0'],
#  ['1846', '43', '0', '0', '43', '0', '0'],
#  ['1847', '46', '0', '0', '46', '0', '0'],
#  ['1848', '47', '0', '0', '47', '0', '0'],
#  ['1849', '50', '0', '0', '50', '0', '0'],
#  ['1850', '54', '0', '0', '54', '0', '0'],
#  ['1851', '54', '0', '0', '54', '0', '0'],
#  ['1852', '57', '0', '0', '57', '0', '0'],
#  ['1853', '59', '0', '0', '59', '0', '0'],
#  ['1854', '69', '0', '0', '69', '0', '0'],
#  ['1855', '71', '0', '0', '71', '0', '0'],
#  ['1856', '76', '0', '0', '76', '0', '0'],
#  ['1857', '77', '0', '0', '77', '0', '0'],
#  ['1858', '78', '0', '0', '78', '0', '0'],
#  ['1859', '83', '0', '0', '83', '0', '0'],
#  ['1860', '91', '0', '0', '91', '0', '0'],
#  ['1861', '95', '0', '0', '95', '0', '0'],
#  ['1862', '97', '0', '0', '96', '0', '0'],
#  ['1863', '104', '0', '0', '103', '0', '0'],
#  ['1864', '112', '0', '0', '112', '0', '0'],
#  ['1865', '119', '0', '0', '119', '0', '0'],
#  ['1866', '122', '0', '0', '122', '0', '0'],
#  ['1867', '130', '0', '0', '130', '0', '0'],
#  ['1868', '135', '0', '0', '134', '0', '0'],
#  ['1869', '142', '0', '0', '142', '0', '0'],
#  ['1870', '147', '0', '1', '146', '0', '0'],
#  ['1871', '156', '0', '1', '156', '0', '0'],
#  ['1872', '173', '0', '1', '173', '0', '0'],
#  ['1873', '184', '0', '1', '183', '0', '0'],
#  ['1874', '174', '0', '1', '173', '0', '0'],
#  ['1875', '188', '0', '1', '187', '0', '0'],
#  ['1876', '191', '0', '1', '190', '0', '0'],
#  ['1877', '194', '0', '2', '192', '0', '0'],
#  ['1878', '196', '0', '2', '194', '0', '0'],
#  ['1879', '210', '0', '3', '207', '0', '0'],
#  ['1880', '236', '0', '3', '233', '0', '0'],
#  ['1881', '243', '0', '4', '239', '0', '0'],
#  ['1882', '256', '0', '4', '252', '0', '0'],
#  ['1883', '272', '0', '3', '269', '0', '0'],
#  ['1884', '275', '0', '4', '271', '0', '0'],
#  ['1885', '277', '1', '4', '273', '0', '0'],
#  ['1886', '281', '2', '5', '275', '0', '0'],
#  ['1887', '295', '3', '5', '287', '0', '0'],
#  ['1888', '327', '5', '5', '317', '0', '0'],
#  ['1889', '327', '3', '6', '318', '0', '0'],
#  ['1890', '356', '3', '8', '345', '0', '0'],
#  ['1891', '372', '2', '9', '360', '0', '0'],
#  ['1892', '374', '2', '9', '363', '0', '0'],
#  ['1893', '370', '2', '10', '358', '0', '0'],
#  ['1894', '383', '2', '9', '372', '0', '0'],
#  ['1895', '406', '2', '11', '393', '0', '0'],
#  ['1896', '419', '2', '12', '405', '0', '0'],
#  ['1897', '440', '2', '13', '425', '0', '0'],
#  ['1898', '465', '2', '13', '449', '0', '0'],
#  ['1899', '507', '3', '14', '491', '0', '0'],
#  ['1900', '534', '3', '16', '515', '0', '0'],
#  ['1901', '552', '4', '18', '531', '0', '0'],
#  ['1902', '566', '4', '19', '543', '0', '0'],
#  ['1903', '617', '4', '20', '593', '0', '0'],
#  ['1904', '624', '4', '23', '597', '0', '0'],
#  ['1905', '663', '5', '23', '636', '0', '0'],
#  ['1906', '707', '5', '23', '680', '0', '0'],
#  ['1907', '784', '5', '28', '750', '0', '0'],
#  ['1908', '750', '5', '30', '714', '0', '0'],
#  ['1909', '785', '6', '32', '747', '0', '0'],
#  ['1910', '819', '7', '34', '778', '0', '0'],
#  ['1911', '836', '7', '36', '792', '0', '0'],
#  ['1912', '879', '8', '37', '834', '0', '0'],
#  ['1913', '943', '8', '41', '895', '0', '0'],
#  ['1914', '850', '8', '42', '800', '0', '0'],
#  ['1915', '838', '9', '45', '784', '0', '0'],
#  ['1916', '901', '10', '48', '842', '0', '0'],
#  ['1917', '955', '11', '54', '891', '0', '0'],
#  ['1918', '936', '10', '53', '873', '0', '0'],
#  ['1919', '806', '10', '61', '735', '0', '0'],
#  ['1920', '932', '11', '78', '843', '0', '0'],
#  ['1921', '803', '10', '84', '709', '0', '0'],
#  ['1922', '845', '11', '94', '740', '0', '0'],
#  ['1923', '970', '14', '111', '845', '0', '0'],
#  ['1924', '963', '16', '110', '836', '0', '0'],
#  ['1925', '975', '17', '116', '842', '0', '0'],
#  ['1926', '983', '19', '119', '846', '0', '0'],
#  ['1927', '1062', '21', '136', '905', '0', '0'],
#  ['1928', '1065', '23', '143', '890', '10', '0'],
#  ['1929', '1145', '28', '160', '947', '10', '0'],
#  ['1930', '1053', '28', '152', '862', '10', '0'],
#  ['1931', '940', '25', '147', '759', '8', '0'],
#  ['1932', '847', '24', '141', '675', '7', '0'],
#  ['1933', '893', '25', '154', '708', '7', '0'],
#  ['1934', '973', '28', '162', '775', '8', '0'],
#  ['1935', '1027', '30', '176', '811', '9', '0'],
#  ['1936', '1130', '34', '192', '893', '11', '0'],
#  ['1937', '1209', '38', '219', '941', '11', '0'],
#  ['1938', '1142', '37', '214', '880', '12', '0'],
#  ['1939', '1192', '38', '222', '918', '13', '0'],
#  ['1940', '1299', '42', '229', '1017', '11', '0'],
#  ['1941', '1334', '42', '236', '1043', '12', '0'],
#  ['1942', '1342', '45', '222', '1063', '11', '0'],
#  ['1943', '1391', '50', '239', '1092', '10', '0'],
#  ['1944', '1383', '54', '275', '1047', '7', '0'],
#  ['1945', '1160', '59', '275', '820', '7', '0'],
#  ['1946', '1238', '61', '292', '875', '10', '0'],
#  ['1947', '1392', '67', '322', '992', '12', '0'],
#  ['1948', '1469', '76', '364', '1015', '14', '0'],
#  ['1949', '1419', '81', '362', '960', '16', '0'],
#  ['1950', '1630', '97', '423', '1070', '18', '23', '0.65'],
#  ['1951', '1767', '115', '479', '1129', '20', '24', '0.69'],
#  ['1952', '1795', '124', '504', '1119', '22', '26', '0.69'],
#  ['1953', '1841', '131', '533', '1125', '24', '27', '0.69'],
#  ['1954', '1865', '138', '557', '1116', '27', '27', '0.69'],
#  ['1955', '2042', '150', '625', '1208', '30', '31', '0.74'],
#  ['1956', '2177', '161', '679', '1273', '32', '32', '0.78'],
#  ['1957', '2270', '178', '714', '1309', '34', '35', '0.79'],
#  ['1958', '2330', '192', '731', '1336', '36', '35', '0.80'],
#  ['1959', '2454', '206', '789', '1382', '40', '36', '0.83'],
#  ['1960', '2569', '227', '849', '1410', '43', '39', '0.85'],
#  ['1961', '2580', '240', '904', '1349', '45', '42', '0.84'],
#  ['1962', '2686', '263', '980', '1351', '49', '44', '0.86'],
#  ['1963', '2833', '286', '1052', '1396', '51', '47', '0.89'],
#  ['1964', '2995', '316', '1137', '1435', '57', '51', '0.92'],
#  ['1965', '3130', '337', '1219', '1460', '59', '55', '0.94'],
#  ['1966', '3288', '364', '1323', '1478', '63', '60', '0.97'],
#  ['1967', '3393', '392', '1423', '1448', '65', '66', '0.98'],
#  ['1968', '3566', '424', '1551', '1448', '70', '73', '1.01'],
#  ['1969', '3780', '467', '1673', '1486', '74', '80', '1.05'],
#  ['1970', '4053', '493', '1839', '1556', '78', '87', '1.10'],
#  ['1971', '4208', '530', '1947', '1559', '84', '88', '1.12'],
#  ['1972', '4376', '560', '2057', '1576', '89', '95', '1.14'],
#  ['1973', '4614', '588', '2241', '1581', '95', '110', '1.18'],
#  ['1974', '4623', '597', '2245', '1579', '96', '107', '1.16'],
#  ['1975', '4596', '604', '2132', '1673', '95', '92', '1.13'],
#  ['1976', '4864', '630', '2314', '1710', '103', '108', '1.18'],
#  ['1977', '5016', '650', '2398', '1756', '108', '104', '1.19'],
#  ['1978', '5074', '680', '2392', '1780', '116', '106', '1.18'],
#  ['1979', '5357', '721', '2544', '1875', '119', '98', '1.23'],
#  ['1980', '5301', '737', '2422', '1935', '120', '86', '1.19'],
#  ['1981', '5138', '755', '2289', '1908', '121', '65', '1.14'],
#  ['1982', '5094', '738', '2196', '1976', '121', '64', '1.11'],
#  ['1983', '5075', '739', '2176', '1977', '125', '58', '1.08'],
#  ['1984', '5258', '807', '2199', '2074', '128', '51', '1.10'],
#  ['1985', '5417', '835', '2186', '2216', '131', '49', '1.12'],
#  ['1986', '5583', '830', '2293', '2277', '137', '46', '1.13'],
#  ['1987', '5725', '892', '2306', '2339', '143', '44', '1.14'],
#  ['1988', '5936', '935', '2412', '2387', '152', '50', '1.16'],
#  ['1989', '6066', '982', '2459', '2428', '156', '41', '1.16'],
#  ['1990', '6096', '1024', '2490', '2384', '157', '40', '1.15'],
#  ['1991', '6171', '1050', '2603', '2312', '161', '45', '1.14'],
#  ['1992', '6110', '1084', '2500', '2323', '167', '36', '1.11'],
#  ['1993', '6104', '1117', '2513', '2262', '176', '37', '1.10'],
#  ['1994', '6208', '1133', '2535', '2315', '186', '39', '1.10'],
#  ['1995', '6344', '1152', '2559', '2398', '197', '39', '1.11'],
#  ['1996', '6491', '1200', '2626', '2422', '203', '40', '1.12'],
#  ['1997', '6589', '1195', '2699', '2445', '209', '40', '1.12'],
#  ['1998', '6571', '1225', '2758', '2343', '209', '36', '1.10'],
#  ['1999', '6559', '1258', '2740', '2309', '217', '35', '1.08'],
#  ['2000', '6727', '1285', '2843', '2327', '226', '46', '1.10'],
#  ['2001', '6886', '1312', '2845', '2445', '237', '47', '1.11'],
#  ['2002', '6946', '1345', '2831', '2468', '252', '49', '1.11'],
#  ['2003', '7367', '1390', '2959', '2694', '276', '48', '1.16'],
#  ['2004', '7735', '1435', '3044', '2904', '298', '54', '1.20'],
#  ['2005', '8025', '1477', '3069', '3098', '320', '60', '1.23'],
#  ['2006', '8307', '1530', '3092', '3267', '356', '62', '1.26'],
#  ['2007', '8488', '1561', '3098', '3382', '382', '66', '1.27'],
#  ['2008', '8738', '1626', '3125', '3530', '388', '69', '1.29'],
#  ['2009', '8641', '1580', '3065', '3517', '415', '64', '1.26'],
#  ['2010', '9137', '1700', '3129', '3795', '448', '66', '1.32'],
#  ['2011', '9508', '1762', '3158', '4027', '496', '64', '1.36'],
#  ['2012', '9671', '1787', '3214', '4086', '520', '65', '1.36'],
#  ['2013', '9776', '1806', '3216', '4131', '554', '68', '1.36']]

# %%
header = co2_list[0]
co2_dict = {}
for line in co2_list[1:]:
    if len(line) < 8:
        for number in range(len(line)):
            line[number] = int(line[number])
        line.append('Unknown')
    elif len(line) == 8:
        for number in range(len(line)-1):
            line[number] = int(line[number])        
        line[-1] = float(line[-1])
    co2_dict[line[0]] = {header[i]: line[i] for i in range(1, len(header))}
co2_dict
# Out:
# {1751: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1752: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1753: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1754: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1755: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1756: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1757: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1758: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1759: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1760: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1761: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1762: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1763: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1764: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1765: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1766: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1767: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1768: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1769: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1770: {'Total': 3,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 3,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1771: {'Total': 4,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 4,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1772: {'Total': 4,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 4,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1773: {'Total': 4,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 4,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1774: {'Total': 4,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 4,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1775: {'Total': 4,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 4,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1776: {'Total': 4,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 4,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1777: {'Total': 4,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 4,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1778: {'Total': 4,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 4,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1779: {'Total': 4,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 4,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1780: {'Total': 4,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 4,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1781: {'Total': 5,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 5,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1782: {'Total': 5,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 5,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1783: {'Total': 5,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 5,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1784: {'Total': 5,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 5,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1785: {'Total': 5,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 5,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1786: {'Total': 5,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 5,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1787: {'Total': 5,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 5,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1788: {'Total': 5,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 5,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1789: {'Total': 5,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 5,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1790: {'Total': 5,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 5,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1791: {'Total': 6,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 6,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1792: {'Total': 6,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 6,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1793: {'Total': 6,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 6,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1794: {'Total': 6,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 6,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1795: {'Total': 6,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 6,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1796: {'Total': 6,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 6,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1797: {'Total': 7,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 7,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1798: {'Total': 7,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 7,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1799: {'Total': 7,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 7,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1800: {'Total': 8,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 8,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1801: {'Total': 8,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 8,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1802: {'Total': 10,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 10,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1803: {'Total': 9,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 9,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1804: {'Total': 9,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 9,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1805: {'Total': 9,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 9,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1806: {'Total': 10,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 10,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1807: {'Total': 10,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 10,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1808: {'Total': 10,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 10,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1809: {'Total': 10,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 10,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1810: {'Total': 10,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 10,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1811: {'Total': 11,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 11,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1812: {'Total': 11,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 11,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1813: {'Total': 11,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 11,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1814: {'Total': 11,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 11,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1815: {'Total': 12,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 12,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1816: {'Total': 13,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 13,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1817: {'Total': 14,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 14,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1818: {'Total': 14,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 14,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1819: {'Total': 14,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 14,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1820: {'Total': 14,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 14,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1821: {'Total': 14,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 14,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1822: {'Total': 15,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 15,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1823: {'Total': 16,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 16,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1824: {'Total': 16,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 16,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1825: {'Total': 17,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 17,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1826: {'Total': 17,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 17,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1827: {'Total': 18,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 18,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1828: {'Total': 18,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 18,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1829: {'Total': 18,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 18,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1830: {'Total': 24,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 24,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1831: {'Total': 23,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 23,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1832: {'Total': 23,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 23,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1833: {'Total': 24,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 24,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1834: {'Total': 24,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 24,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1835: {'Total': 25,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 25,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1836: {'Total': 29,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 29,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1837: {'Total': 29,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 29,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1838: {'Total': 30,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 30,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1839: {'Total': 31,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 31,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1840: {'Total': 33,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 33,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1841: {'Total': 34,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 34,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1842: {'Total': 36,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 36,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1843: {'Total': 37,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 37,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1844: {'Total': 39,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 39,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1845: {'Total': 43,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 43,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1846: {'Total': 43,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 43,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1847: {'Total': 46,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 46,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1848: {'Total': 47,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 47,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1849: {'Total': 50,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 50,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1850: {'Total': 54,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 54,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1851: {'Total': 54,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 54,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1852: {'Total': 57,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 57,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1853: {'Total': 59,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 59,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1854: {'Total': 69,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 69,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1855: {'Total': 71,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 71,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1856: {'Total': 76,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 76,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1857: {'Total': 77,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 77,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1858: {'Total': 78,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 78,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1859: {'Total': 83,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 83,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1860: {'Total': 91,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 91,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1861: {'Total': 95,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 95,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1862: {'Total': 97,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 96,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1863: {'Total': 104,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 103,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1864: {'Total': 112,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 112,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1865: {'Total': 119,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 119,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1866: {'Total': 122,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 122,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1867: {'Total': 130,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 130,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1868: {'Total': 135,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 134,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1869: {'Total': 142,
#   'Gas': 0,
#   'Liquids': 0,
#   'Solids': 142,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1870: {'Total': 147,
#   'Gas': 0,
#   'Liquids': 1,
#   'Solids': 146,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1871: {'Total': 156,
#   'Gas': 0,
#   'Liquids': 1,
#   'Solids': 156,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1872: {'Total': 173,
#   'Gas': 0,
#   'Liquids': 1,
#   'Solids': 173,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1873: {'Total': 184,
#   'Gas': 0,
#   'Liquids': 1,
#   'Solids': 183,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1874: {'Total': 174,
#   'Gas': 0,
#   'Liquids': 1,
#   'Solids': 173,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1875: {'Total': 188,
#   'Gas': 0,
#   'Liquids': 1,
#   'Solids': 187,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1876: {'Total': 191,
#   'Gas': 0,
#   'Liquids': 1,
#   'Solids': 190,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1877: {'Total': 194,
#   'Gas': 0,
#   'Liquids': 2,
#   'Solids': 192,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1878: {'Total': 196,
#   'Gas': 0,
#   'Liquids': 2,
#   'Solids': 194,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1879: {'Total': 210,
#   'Gas': 0,
#   'Liquids': 3,
#   'Solids': 207,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1880: {'Total': 236,
#   'Gas': 0,
#   'Liquids': 3,
#   'Solids': 233,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1881: {'Total': 243,
#   'Gas': 0,
#   'Liquids': 4,
#   'Solids': 239,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1882: {'Total': 256,
#   'Gas': 0,
#   'Liquids': 4,
#   'Solids': 252,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1883: {'Total': 272,
#   'Gas': 0,
#   'Liquids': 3,
#   'Solids': 269,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1884: {'Total': 275,
#   'Gas': 0,
#   'Liquids': 4,
#   'Solids': 271,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1885: {'Total': 277,
#   'Gas': 1,
#   'Liquids': 4,
#   'Solids': 273,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1886: {'Total': 281,
#   'Gas': 2,
#   'Liquids': 5,
#   'Solids': 275,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1887: {'Total': 295,
#   'Gas': 3,
#   'Liquids': 5,
#   'Solids': 287,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1888: {'Total': 327,
#   'Gas': 5,
#   'Liquids': 5,
#   'Solids': 317,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1889: {'Total': 327,
#   'Gas': 3,
#   'Liquids': 6,
#   'Solids': 318,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1890: {'Total': 356,
#   'Gas': 3,
#   'Liquids': 8,
#   'Solids': 345,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1891: {'Total': 372,
#   'Gas': 2,
#   'Liquids': 9,
#   'Solids': 360,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1892: {'Total': 374,
#   'Gas': 2,
#   'Liquids': 9,
#   'Solids': 363,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1893: {'Total': 370,
#   'Gas': 2,
#   'Liquids': 10,
#   'Solids': 358,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1894: {'Total': 383,
#   'Gas': 2,
#   'Liquids': 9,
#   'Solids': 372,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1895: {'Total': 406,
#   'Gas': 2,
#   'Liquids': 11,
#   'Solids': 393,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1896: {'Total': 419,
#   'Gas': 2,
#   'Liquids': 12,
#   'Solids': 405,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1897: {'Total': 440,
#   'Gas': 2,
#   'Liquids': 13,
#   'Solids': 425,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1898: {'Total': 465,
#   'Gas': 2,
#   'Liquids': 13,
#   'Solids': 449,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1899: {'Total': 507,
#   'Gas': 3,
#   'Liquids': 14,
#   'Solids': 491,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1900: {'Total': 534,
#   'Gas': 3,
#   'Liquids': 16,
#   'Solids': 515,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1901: {'Total': 552,
#   'Gas': 4,
#   'Liquids': 18,
#   'Solids': 531,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1902: {'Total': 566,
#   'Gas': 4,
#   'Liquids': 19,
#   'Solids': 543,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1903: {'Total': 617,
#   'Gas': 4,
#   'Liquids': 20,
#   'Solids': 593,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1904: {'Total': 624,
#   'Gas': 4,
#   'Liquids': 23,
#   'Solids': 597,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1905: {'Total': 663,
#   'Gas': 5,
#   'Liquids': 23,
#   'Solids': 636,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1906: {'Total': 707,
#   'Gas': 5,
#   'Liquids': 23,
#   'Solids': 680,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1907: {'Total': 784,
#   'Gas': 5,
#   'Liquids': 28,
#   'Solids': 750,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1908: {'Total': 750,
#   'Gas': 5,
#   'Liquids': 30,
#   'Solids': 714,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1909: {'Total': 785,
#   'Gas': 6,
#   'Liquids': 32,
#   'Solids': 747,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1910: {'Total': 819,
#   'Gas': 7,
#   'Liquids': 34,
#   'Solids': 778,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1911: {'Total': 836,
#   'Gas': 7,
#   'Liquids': 36,
#   'Solids': 792,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1912: {'Total': 879,
#   'Gas': 8,
#   'Liquids': 37,
#   'Solids': 834,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1913: {'Total': 943,
#   'Gas': 8,
#   'Liquids': 41,
#   'Solids': 895,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1914: {'Total': 850,
#   'Gas': 8,
#   'Liquids': 42,
#   'Solids': 800,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1915: {'Total': 838,
#   'Gas': 9,
#   'Liquids': 45,
#   'Solids': 784,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1916: {'Total': 901,
#   'Gas': 10,
#   'Liquids': 48,
#   'Solids': 842,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1917: {'Total': 955,
#   'Gas': 11,
#   'Liquids': 54,
#   'Solids': 891,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1918: {'Total': 936,
#   'Gas': 10,
#   'Liquids': 53,
#   'Solids': 873,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1919: {'Total': 806,
#   'Gas': 10,
#   'Liquids': 61,
#   'Solids': 735,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1920: {'Total': 932,
#   'Gas': 11,
#   'Liquids': 78,
#   'Solids': 843,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1921: {'Total': 803,
#   'Gas': 10,
#   'Liquids': 84,
#   'Solids': 709,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1922: {'Total': 845,
#   'Gas': 11,
#   'Liquids': 94,
#   'Solids': 740,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1923: {'Total': 970,
#   'Gas': 14,
#   'Liquids': 111,
#   'Solids': 845,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1924: {'Total': 963,
#   'Gas': 16,
#   'Liquids': 110,
#   'Solids': 836,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1925: {'Total': 975,
#   'Gas': 17,
#   'Liquids': 116,
#   'Solids': 842,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1926: {'Total': 983,
#   'Gas': 19,
#   'Liquids': 119,
#   'Solids': 846,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1927: {'Total': 1062,
#   'Gas': 21,
#   'Liquids': 136,
#   'Solids': 905,
#   'Cement_Production': 0,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1928: {'Total': 1065,
#   'Gas': 23,
#   'Liquids': 143,
#   'Solids': 890,
#   'Cement_Production': 10,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1929: {'Total': 1145,
#   'Gas': 28,
#   'Liquids': 160,
#   'Solids': 947,
#   'Cement_Production': 10,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1930: {'Total': 1053,
#   'Gas': 28,
#   'Liquids': 152,
#   'Solids': 862,
#   'Cement_Production': 10,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1931: {'Total': 940,
#   'Gas': 25,
#   'Liquids': 147,
#   'Solids': 759,
#   'Cement_Production': 8,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1932: {'Total': 847,
#   'Gas': 24,
#   'Liquids': 141,
#   'Solids': 675,
#   'Cement_Production': 7,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1933: {'Total': 893,
#   'Gas': 25,
#   'Liquids': 154,
#   'Solids': 708,
#   'Cement_Production': 7,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1934: {'Total': 973,
#   'Gas': 28,
#   'Liquids': 162,
#   'Solids': 775,
#   'Cement_Production': 8,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1935: {'Total': 1027,
#   'Gas': 30,
#   'Liquids': 176,
#   'Solids': 811,
#   'Cement_Production': 9,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1936: {'Total': 1130,
#   'Gas': 34,
#   'Liquids': 192,
#   'Solids': 893,
#   'Cement_Production': 11,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1937: {'Total': 1209,
#   'Gas': 38,
#   'Liquids': 219,
#   'Solids': 941,
#   'Cement_Production': 11,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1938: {'Total': 1142,
#   'Gas': 37,
#   'Liquids': 214,
#   'Solids': 880,
#   'Cement_Production': 12,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1939: {'Total': 1192,
#   'Gas': 38,
#   'Liquids': 222,
#   'Solids': 918,
#   'Cement_Production': 13,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1940: {'Total': 1299,
#   'Gas': 42,
#   'Liquids': 229,
#   'Solids': 1017,
#   'Cement_Production': 11,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1941: {'Total': 1334,
#   'Gas': 42,
#   'Liquids': 236,
#   'Solids': 1043,
#   'Cement_Production': 12,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1942: {'Total': 1342,
#   'Gas': 45,
#   'Liquids': 222,
#   'Solids': 1063,
#   'Cement_Production': 11,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1943: {'Total': 1391,
#   'Gas': 50,
#   'Liquids': 239,
#   'Solids': 1092,
#   'Cement_Production': 10,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1944: {'Total': 1383,
#   'Gas': 54,
#   'Liquids': 275,
#   'Solids': 1047,
#   'Cement_Production': 7,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1945: {'Total': 1160,
#   'Gas': 59,
#   'Liquids': 275,
#   'Solids': 820,
#   'Cement_Production': 7,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1946: {'Total': 1238,
#   'Gas': 61,
#   'Liquids': 292,
#   'Solids': 875,
#   'Cement_Production': 10,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1947: {'Total': 1392,
#   'Gas': 67,
#   'Liquids': 322,
#   'Solids': 992,
#   'Cement_Production': 12,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1948: {'Total': 1469,
#   'Gas': 76,
#   'Liquids': 364,
#   'Solids': 1015,
#   'Cement_Production': 14,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1949: {'Total': 1419,
#   'Gas': 81,
#   'Liquids': 362,
#   'Solids': 960,
#   'Cement_Production': 16,
#   'Gas_Flaring': 0,
#   'Per_Capita': 'Unknown'},
#  1950: {'Total': 1630,
#   'Gas': 97,
#   'Liquids': 423,
#   'Solids': 1070,
#   'Cement_Production': 18,
#   'Gas_Flaring': 23,
#   'Per_Capita': 0.65},
#  1951: {'Total': 1767,
#   'Gas': 115,
#   'Liquids': 479,
#   'Solids': 1129,
#   'Cement_Production': 20,
#   'Gas_Flaring': 24,
#   'Per_Capita': 0.69},
#  1952: {'Total': 1795,
#   'Gas': 124,
#   'Liquids': 504,
#   'Solids': 1119,
#   'Cement_Production': 22,
#   'Gas_Flaring': 26,
#   'Per_Capita': 0.69},
#  1953: {'Total': 1841,
#   'Gas': 131,
#   'Liquids': 533,
#   'Solids': 1125,
#   'Cement_Production': 24,
#   'Gas_Flaring': 27,
#   'Per_Capita': 0.69},
#  1954: {'Total': 1865,
#   'Gas': 138,
#   'Liquids': 557,
#   'Solids': 1116,
#   'Cement_Production': 27,
#   'Gas_Flaring': 27,
#   'Per_Capita': 0.69},
#  1955: {'Total': 2042,
#   'Gas': 150,
#   'Liquids': 625,
#   'Solids': 1208,
#   'Cement_Production': 30,
#   'Gas_Flaring': 31,
#   'Per_Capita': 0.74},
#  1956: {'Total': 2177,
#   'Gas': 161,
#   'Liquids': 679,
#   'Solids': 1273,
#   'Cement_Production': 32,
#   'Gas_Flaring': 32,
#   'Per_Capita': 0.78},
#  1957: {'Total': 2270,
#   'Gas': 178,
#   'Liquids': 714,
#   'Solids': 1309,
#   'Cement_Production': 34,
#   'Gas_Flaring': 35,
#   'Per_Capita': 0.79},
#  1958: {'Total': 2330,
#   'Gas': 192,
#   'Liquids': 731,
#   'Solids': 1336,
#   'Cement_Production': 36,
#   'Gas_Flaring': 35,
#   'Per_Capita': 0.8},
#  1959: {'Total': 2454,
#   'Gas': 206,
#   'Liquids': 789,
#   'Solids': 1382,
#   'Cement_Production': 40,
#   'Gas_Flaring': 36,
#   'Per_Capita': 0.83},
#  1960: {'Total': 2569,
#   'Gas': 227,
#   'Liquids': 849,
#   'Solids': 1410,
#   'Cement_Production': 43,
#   'Gas_Flaring': 39,
#   'Per_Capita': 0.85},
#  1961: {'Total': 2580,
#   'Gas': 240,
#   'Liquids': 904,
#   'Solids': 1349,
#   'Cement_Production': 45,
#   'Gas_Flaring': 42,
#   'Per_Capita': 0.84},
#  1962: {'Total': 2686,
#   'Gas': 263,
#   'Liquids': 980,
#   'Solids': 1351,
#   'Cement_Production': 49,
#   'Gas_Flaring': 44,
#   'Per_Capita': 0.86},
#  1963: {'Total': 2833,
#   'Gas': 286,
#   'Liquids': 1052,
#   'Solids': 1396,
#   'Cement_Production': 51,
#   'Gas_Flaring': 47,
#   'Per_Capita': 0.89},
#  1964: {'Total': 2995,
#   'Gas': 316,
#   'Liquids': 1137,
#   'Solids': 1435,
#   'Cement_Production': 57,
#   'Gas_Flaring': 51,
#   'Per_Capita': 0.92},
#  1965: {'Total': 3130,
#   'Gas': 337,
#   'Liquids': 1219,
#   'Solids': 1460,
#   'Cement_Production': 59,
#   'Gas_Flaring': 55,
#   'Per_Capita': 0.94},
#  1966: {'Total': 3288,
#   'Gas': 364,
#   'Liquids': 1323,
#   'Solids': 1478,
#   'Cement_Production': 63,
#   'Gas_Flaring': 60,
#   'Per_Capita': 0.97},
#  1967: {'Total': 3393,
#   'Gas': 392,
#   'Liquids': 1423,
#   'Solids': 1448,
#   'Cement_Production': 65,
#   'Gas_Flaring': 66,
#   'Per_Capita': 0.98},
#  1968: {'Total': 3566,
#   'Gas': 424,
#   'Liquids': 1551,
#   'Solids': 1448,
#   'Cement_Production': 70,
#   'Gas_Flaring': 73,
#   'Per_Capita': 1.01},
#  1969: {'Total': 3780,
#   'Gas': 467,
#   'Liquids': 1673,
#   'Solids': 1486,
#   'Cement_Production': 74,
#   'Gas_Flaring': 80,
#   'Per_Capita': 1.05},
#  1970: {'Total': 4053,
#   'Gas': 493,
#   'Liquids': 1839,
#   'Solids': 1556,
#   'Cement_Production': 78,
#   'Gas_Flaring': 87,
#   'Per_Capita': 1.1},
#  1971: {'Total': 4208,
#   'Gas': 530,
#   'Liquids': 1947,
#   'Solids': 1559,
#   'Cement_Production': 84,
#   'Gas_Flaring': 88,
#   'Per_Capita': 1.12},
#  1972: {'Total': 4376,
#   'Gas': 560,
#   'Liquids': 2057,
#   'Solids': 1576,
#   'Cement_Production': 89,
#   'Gas_Flaring': 95,
#   'Per_Capita': 1.14},
#  1973: {'Total': 4614,
#   'Gas': 588,
#   'Liquids': 2241,
#   'Solids': 1581,
#   'Cement_Production': 95,
#   'Gas_Flaring': 110,
#   'Per_Capita': 1.18},
#  1974: {'Total': 4623,
#   'Gas': 597,
#   'Liquids': 2245,
#   'Solids': 1579,
#   'Cement_Production': 96,
#   'Gas_Flaring': 107,
#   'Per_Capita': 1.16},
#  1975: {'Total': 4596,
#   'Gas': 604,
#   'Liquids': 2132,
#   'Solids': 1673,
#   'Cement_Production': 95,
#   'Gas_Flaring': 92,
#   'Per_Capita': 1.13},
#  1976: {'Total': 4864,
#   'Gas': 630,
#   'Liquids': 2314,
#   'Solids': 1710,
#   'Cement_Production': 103,
#   'Gas_Flaring': 108,
#   'Per_Capita': 1.18},
#  1977: {'Total': 5016,
#   'Gas': 650,
#   'Liquids': 2398,
#   'Solids': 1756,
#   'Cement_Production': 108,
#   'Gas_Flaring': 104,
#   'Per_Capita': 1.19},
#  1978: {'Total': 5074,
#   'Gas': 680,
#   'Liquids': 2392,
#   'Solids': 1780,
#   'Cement_Production': 116,
#   'Gas_Flaring': 106,
#   'Per_Capita': 1.18},
#  1979: {'Total': 5357,
#   'Gas': 721,
#   'Liquids': 2544,
#   'Solids': 1875,
#   'Cement_Production': 119,
#   'Gas_Flaring': 98,
#   'Per_Capita': 1.23},
#  1980: {'Total': 5301,
#   'Gas': 737,
#   'Liquids': 2422,
#   'Solids': 1935,
#   'Cement_Production': 120,
#   'Gas_Flaring': 86,
#   'Per_Capita': 1.19},
#  1981: {'Total': 5138,
#   'Gas': 755,
#   'Liquids': 2289,
#   'Solids': 1908,
#   'Cement_Production': 121,
#   'Gas_Flaring': 65,
#   'Per_Capita': 1.14},
#  1982: {'Total': 5094,
#   'Gas': 738,
#   'Liquids': 2196,
#   'Solids': 1976,
#   'Cement_Production': 121,
#   'Gas_Flaring': 64,
#   'Per_Capita': 1.11},
#  1983: {'Total': 5075,
#   'Gas': 739,
#   'Liquids': 2176,
#   'Solids': 1977,
#   'Cement_Production': 125,
#   'Gas_Flaring': 58,
#   'Per_Capita': 1.08},
#  1984: {'Total': 5258,
#   'Gas': 807,
#   'Liquids': 2199,
#   'Solids': 2074,
#   'Cement_Production': 128,
#   'Gas_Flaring': 51,
#   'Per_Capita': 1.1},
#  1985: {'Total': 5417,
#   'Gas': 835,
#   'Liquids': 2186,
#   'Solids': 2216,
#   'Cement_Production': 131,
#   'Gas_Flaring': 49,
#   'Per_Capita': 1.12},
#  1986: {'Total': 5583,
#   'Gas': 830,
#   'Liquids': 2293,
#   'Solids': 2277,
#   'Cement_Production': 137,
#   'Gas_Flaring': 46,
#   'Per_Capita': 1.13},
#  1987: {'Total': 5725,
#   'Gas': 892,
#   'Liquids': 2306,
#   'Solids': 2339,
#   'Cement_Production': 143,
#   'Gas_Flaring': 44,
#   'Per_Capita': 1.14},
#  1988: {'Total': 5936,
#   'Gas': 935,
#   'Liquids': 2412,
#   'Solids': 2387,
#   'Cement_Production': 152,
#   'Gas_Flaring': 50,
#   'Per_Capita': 1.16},
#  1989: {'Total': 6066,
#   'Gas': 982,
#   'Liquids': 2459,
#   'Solids': 2428,
#   'Cement_Production': 156,
#   'Gas_Flaring': 41,
#   'Per_Capita': 1.16},
#  1990: {'Total': 6096,
#   'Gas': 1024,
#   'Liquids': 2490,
#   'Solids': 2384,
#   'Cement_Production': 157,
#   'Gas_Flaring': 40,
#   'Per_Capita': 1.15},
#  1991: {'Total': 6171,
#   'Gas': 1050,
#   'Liquids': 2603,
#   'Solids': 2312,
#   'Cement_Production': 161,
#   'Gas_Flaring': 45,
#   'Per_Capita': 1.14},
#  1992: {'Total': 6110,
#   'Gas': 1084,
#   'Liquids': 2500,
#   'Solids': 2323,
#   'Cement_Production': 167,
#   'Gas_Flaring': 36,
#   'Per_Capita': 1.11},
#  1993: {'Total': 6104,
#   'Gas': 1117,
#   'Liquids': 2513,
#   'Solids': 2262,
#   'Cement_Production': 176,
#   'Gas_Flaring': 37,
#   'Per_Capita': 1.1},
#  1994: {'Total': 6208,
#   'Gas': 1133,
#   'Liquids': 2535,
#   'Solids': 2315,
#   'Cement_Production': 186,
#   'Gas_Flaring': 39,
#   'Per_Capita': 1.1},
#  1995: {'Total': 6344,
#   'Gas': 1152,
#   'Liquids': 2559,
#   'Solids': 2398,
#   'Cement_Production': 197,
#   'Gas_Flaring': 39,
#   'Per_Capita': 1.11},
#  1996: {'Total': 6491,
#   'Gas': 1200,
#   'Liquids': 2626,
#   'Solids': 2422,
#   'Cement_Production': 203,
#   'Gas_Flaring': 40,
#   'Per_Capita': 1.12},
#  1997: {'Total': 6589,
#   'Gas': 1195,
#   'Liquids': 2699,
#   'Solids': 2445,
#   'Cement_Production': 209,
#   'Gas_Flaring': 40,
#   'Per_Capita': 1.12},
#  1998: {'Total': 6571,
#   'Gas': 1225,
#   'Liquids': 2758,
#   'Solids': 2343,
#   'Cement_Production': 209,
#   'Gas_Flaring': 36,
#   'Per_Capita': 1.1},
#  1999: {'Total': 6559,
#   'Gas': 1258,
#   'Liquids': 2740,
#   'Solids': 2309,
#   'Cement_Production': 217,
#   'Gas_Flaring': 35,
#   'Per_Capita': 1.08},
#  2000: {'Total': 6727,
#   'Gas': 1285,
#   'Liquids': 2843,
#   'Solids': 2327,
#   'Cement_Production': 226,
#   'Gas_Flaring': 46,
#   'Per_Capita': 1.1},
#  2001: {'Total': 6886,
#   'Gas': 1312,
#   'Liquids': 2845,
#   'Solids': 2445,
#   'Cement_Production': 237,
#   'Gas_Flaring': 47,
#   'Per_Capita': 1.11},
#  2002: {'Total': 6946,
#   'Gas': 1345,
#   'Liquids': 2831,
#   'Solids': 2468,
#   'Cement_Production': 252,
#   'Gas_Flaring': 49,
#   'Per_Capita': 1.11},
#  2003: {'Total': 7367,
#   'Gas': 1390,
#   'Liquids': 2959,
#   'Solids': 2694,
#   'Cement_Production': 276,
#   'Gas_Flaring': 48,
#   'Per_Capita': 1.16},
#  2004: {'Total': 7735,
#   'Gas': 1435,
#   'Liquids': 3044,
#   'Solids': 2904,
#   'Cement_Production': 298,
#   'Gas_Flaring': 54,
#   'Per_Capita': 1.2},
#  2005: {'Total': 8025,
#   'Gas': 1477,
#   'Liquids': 3069,
#   'Solids': 3098,
#   'Cement_Production': 320,
#   'Gas_Flaring': 60,
#   'Per_Capita': 1.23},
#  2006: {'Total': 8307,
#   'Gas': 1530,
#   'Liquids': 3092,
#   'Solids': 3267,
#   'Cement_Production': 356,
#   'Gas_Flaring': 62,
#   'Per_Capita': 1.26},
#  2007: {'Total': 8488,
#   'Gas': 1561,
#   'Liquids': 3098,
#   'Solids': 3382,
#   'Cement_Production': 382,
#   'Gas_Flaring': 66,
#   'Per_Capita': 1.27},
#  2008: {'Total': 8738,
#   'Gas': 1626,
#   'Liquids': 3125,
#   'Solids': 3530,
#   'Cement_Production': 388,
#   'Gas_Flaring': 69,
#   'Per_Capita': 1.29},
#  2009: {'Total': 8641,
#   'Gas': 1580,
#   'Liquids': 3065,
#   'Solids': 3517,
#   'Cement_Production': 415,
#   'Gas_Flaring': 64,
#   'Per_Capita': 1.26},
#  2010: {'Total': 9137,
#   'Gas': 1700,
#   'Liquids': 3129,
#   'Solids': 3795,
#   'Cement_Production': 448,
#   'Gas_Flaring': 66,
#   'Per_Capita': 1.32},
#  2011: {'Total': 9508,
#   'Gas': 1762,
#   'Liquids': 3158,
#   'Solids': 4027,
#   'Cement_Production': 496,
#   'Gas_Flaring': 64,
#   'Per_Capita': 1.36},
#  2012: {'Total': 9671,
#   'Gas': 1787,
#   'Liquids': 3214,
#   'Solids': 4086,
#   'Cement_Production': 520,
#   'Gas_Flaring': 65,
#   'Per_Capita': 1.36},
#  2013: {'Total': 9776,
#   'Gas': 1806,
#   'Liquids': 3216,
#   'Solids': 4131,
#   'Cement_Production': 554,
#   'Gas_Flaring': 68,
#   'Per_Capita': 1.36}}

# %% [markdown]
# ## Read and Parse Temperature Data
# Read in temperature data {year: {month:temp difference}}

# %%
def read_temp_data(filepath):
    with open(filepath) as f:
        raw_data = f.readlines()
        header = raw_data[0].strip().split()
        data = {}
        for row in raw_data[1:]:
            row = row.strip().split()
            data[int(row[0])] = {header[i] : check_if_value(row[i]) for i in range(1, len(row) - 1)}
    return data

def check_if_value(string, default = None):
    try:
        res = int(eval(str(string)))
        if type(res) == int:
            return res
    except:
        return default

    
temp_dict = read_temp_data("temp_data.txt")
    
print(temp_dict)
#if __name__ == "__main__":
#    data = read_temp_data("temp_data.txt")
#    print("\n".join(["{0} : {1}".format(k, v) for k, v in data.items()]))
# Out:
# {1880: {'Jan': -29, 'Feb': -18, 'Mar': -11, 'Apr': -19, 'May': -11, 'Jun': -23, 'Jul': -21, 'Aug': -9, 'Sep': -16, 'Oct': -23, 'Nov': -20, 'Dec': -22, 'J-D': -18, 'D-N': None, 'DJF': None, 'MAM': -14, 'JJA': -17, 'SON': -20}, 1881: {'Jan': -15, 'Feb': -17, 'Mar': 4, 'Apr': 4, 'May': 2, 'Jun': -20, 'Jul': -7, 'Aug': -2, 'Sep': -14, 'Oct': -21, 'Nov': -22, 'Dec': -11, 'J-D': -10, 'D-N': -11, 'DJF': -18, 'MAM': 3, 'JJA': -10, 'SON': -19}, 1882: {'Jan': 14, 'Feb': 15, 'Mar': 4, 'Apr': -19, 'May': -16, 'Jun': -26, 'Jul': -21, 'Aug': -5, 'Sep': -10, 'Oct': -25, 'Nov': -16, 'Dec': -25, 'J-D': -11, 'D-N': -10, 'DJF': 6, 'MAM': -10, 'JJA': -17, 'SON': -17}, 1883: {'Jan': -32, 'Feb': -39, 'Mar': -13, 'Apr': -17, 'May': -20, 'Jun': -13, 'Jul': -8, 'Aug': -15, 'Sep': -21, 'Oct': -14, 'Nov': -22, 'Dec': -16, 'J-D': -19, 'D-N': -20, 'DJF': -32, 'MAM': -17, 'JJA': -12, 'SON': -19}, 1884: {'Jan': -15, 'Feb': -8, 'Mar': -37, 'Apr': -43, 'May': -37, 'Jun': -41, 'Jul': -35, 'Aug': -26, 'Sep': -27, 'Oct': -24, 'Nov': -30, 'Dec': -29, 'J-D': -29, 'D-N': -28, 'DJF': -13, 'MAM': -39, 'JJA': -34, 'SON': -27}, 1885: {'Jan': -59, 'Feb': -30, 'Mar': -25, 'Apr': -42, 'May': -42, 'Jun': -44, 'Jul': -35, 'Aug': -31, 'Sep': -24, 'Oct': -19, 'Nov': -19, 'Dec': -5, 'J-D': -31, 'D-N': -33, 'DJF': -39, 'MAM': -36, 'JJA': -37, 'SON': -21}, 1886: {'Jan': -42, 'Feb': -45, 'Mar': -38, 'Apr': -28, 'May': -26, 'Jun': -39, 'Jul': -22, 'Aug': -34, 'Sep': -25, 'Oct': -28, 'Nov': -31, 'Dec': -26, 'J-D': -32, 'D-N': -30, 'DJF': -31, 'MAM': -31, 'JJA': -31, 'SON': -28}, 1887: {'Jan': -72, 'Feb': -52, 'Mar': -34, 'Apr': -39, 'May': -32, 'Jun': -24, 'Jul': -23, 'Aug': -32, 'Sep': -22, 'Oct': -33, 'Nov': -23, 'Dec': -33, 'J-D': -35, 'D-N': -34, 'DJF': -50, 'MAM': -35, 'JJA': -26, 'SON': -26}, 1888: {'Jan': -37, 'Feb': -36, 'Mar': -41, 'Apr': -22, 'May': -22, 'Jun': -18, 'Jul': -10, 'Aug': -16, 'Sep': -10, 'Oct': 1, 'Nov': 0, 'Dec': -6, 'J-D': -18, 'D-N': -20, 'DJF': -36, 'MAM': -28, 'JJA': -15, 'SON': -3}, 1889: {'Jan': -11, 'Feb': 18, 'Mar': 8, 'Apr': 7, 'May': -2, 'Jun': -14, 'Jul': -10, 'Aug': -20, 'Sep': -22, 'Oct': -22, 'Nov': -33, 'Dec': -30, 'J-D': -11, 'D-N': -9, 'DJF': 0, 'MAM': 4, 'JJA': -14, 'SON': -26}, 1890: {'Jan': -44, 'Feb': -45, 'Mar': -40, 'Apr': -37, 'May': -46, 'Jun': -27, 'Jul': -26, 'Aug': -38, 'Sep': -39, 'Oct': -24, 'Nov': -48, 'Dec': -31, 'J-D': -37, 'D-N': -37, 'DJF': -40, 'MAM': -41, 'JJA': -30, 'SON': -37}, 1891: {'Jan': -41, 'Feb': -47, 'Mar': -19, 'Apr': -28, 'May': -19, 'Jun': -21, 'Jul': -20, 'Aug': -16, 'Sep': -13, 'Oct': -21, 'Nov': -34, 'Dec': -4, 'J-D': -24, 'D-N': -26, 'DJF': -40, 'MAM': -22, 'JJA': -19, 'SON': -23}, 1892: {'Jan': -28, 'Feb': -11, 'Mar': -35, 'Apr': -35, 'May': -25, 'Jun': -23, 'Jul': -32, 'Aug': -25, 'Sep': -12, 'Oct': -12, 'Nov': -41, 'Dec': -38, 'J-D': -26, 'D-N': -24, 'DJF': -14, 'MAM': -31, 'JJA': -27, 'SON': -22}, 1893: {'Jan': -79, 'Feb': -53, 'Mar': -23, 'Apr': -29, 'May': -36, 'Jun': -28, 'Jul': -15, 'Aug': -26, 'Sep': -20, 'Oct': -16, 'Nov': -16, 'Dec': -34, 'J-D': -31, 'D-N': -32, 'DJF': -57, 'MAM': -29, 'JJA': -23, 'SON': -17}, 1894: {'Jan': -53, 'Feb': -33, 'Mar': -25, 'Apr': -47, 'May': -34, 'Jun': -43, 'Jul': -26, 'Aug': -22, 'Sep': -24, 'Oct': -20, 'Nov': -25, 'Dec': -19, 'J-D': -31, 'D-N': -32, 'DJF': -40, 'MAM': -35, 'JJA': -30, 'SON': -23}, 1895: {'Jan': -44, 'Feb': -42, 'Mar': -28, 'Apr': -24, 'May': -26, 'Jun': -23, 'Jul': -17, 'Aug': -15, 'Sep': -8, 'Oct': -8, 'Nov': -14, 'Dec': -15, 'J-D': -22, 'D-N': -22, 'DJF': -35, 'MAM': -26, 'JJA': -19, 'SON': -10}, 1896: {'Jan': -25, 'Feb': -14, 'Mar': -25, 'Apr': -30, 'May': -18, 'Jun': -13, 'Jul': -3, 'Aug': -3, 'Sep': -2, 'Oct': 12, 'Nov': -7, 'Dec': -3, 'J-D': -11, 'D-N': -12, 'DJF': -18, 'MAM': -24, 'JJA': -6, 'SON': 1}, 1897: {'Jan': -14, 'Feb': -14, 'Mar': -13, 'Apr': -2, 'May': -4, 'Jun': -16, 'Jul': -7, 'Aug': -11, 'Sep': -7, 'Oct': -12, 'Nov': -19, 'Dec': -19, 'J-D': -11, 'D-N': -10, 'DJF': -10, 'MAM': -6, 'JJA': -11, 'SON': -13}, 1898: {'Jan': -3, 'F ...

# %% [markdown]
# ## Obtain Statistics about Temp Data
# Yearly Highs, Lows, Averages, Std Deviation

# %%
import statistics
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
## Get Yearly Statistics for Temperature Data
## Input: Dictionary of Dictionaries {year: {month:temp difference}}
## Output: Dictionary of Dictionaries {year: {statistic: value}}
def temp_stats(temp_dict):
    data = {}
    for year, values in temp_dict.items():
        monthly_val = [values.get(month, None) for month in months if values.get(month, None) is not None]
        data[year] = {'high': max(monthly_val), 'low': min(monthly_val), 'avg': round(statistics.mean(monthly_val))}
    return data

temp_stats = temp_stats(temp_dict)
temp_stats
# Out:
# {1880: {'high': -9, 'low': -29, 'avg': -18},
#  1881: {'high': 4, 'low': -22, 'avg': -10},
#  1882: {'high': 15, 'low': -26, 'avg': -11},
#  1883: {'high': -8, 'low': -39, 'avg': -19},
#  1884: {'high': -8, 'low': -43, 'avg': -29},
#  1885: {'high': -5, 'low': -59, 'avg': -31},
#  1886: {'high': -22, 'low': -45, 'avg': -32},
#  1887: {'high': -22, 'low': -72, 'avg': -35},
#  1888: {'high': 1, 'low': -41, 'avg': -18},
#  1889: {'high': 18, 'low': -33, 'avg': -11},
#  1890: {'high': -24, 'low': -48, 'avg': -37},
#  1891: {'high': -4, 'low': -47, 'avg': -24},
#  1892: {'high': -11, 'low': -41, 'avg': -26},
#  1893: {'high': -15, 'low': -79, 'avg': -31},
#  1894: {'high': -19, 'low': -53, 'avg': -31},
#  1895: {'high': -8, 'low': -44, 'avg': -22},
#  1896: {'high': 12, 'low': -30, 'avg': -11},
#  1897: {'high': -2, 'low': -19, 'avg': -12},
#  1898: {'high': -3, 'low': -51, 'avg': -28},
#  1899: {'high': 12, 'low': -40, 'avg': -18},
#  1900: {'high': 9, 'low': -37, 'avg': -9},
#  1901: {'high': 8, 'low': -30, 'avg': -15},
#  1902: {'high': -3, 'low': -46, 'avg': -30},
#  1903: {'high': -4, 'low': -52, 'avg': -39},
#  1904: {'high': -20, 'low': -67, 'avg': -49},
#  1905: {'high': -9, 'low': -59, 'avg': -28},
#  1906: {'high': -4, 'low': -37, 'avg': -21},
#  1907: {'high': -23, 'low': -50, 'avg': -38},
#  1908: {'high': -30, 'low': -52, 'avg': -42},
#  1909: {'high': -30, 'low': -68, 'avg': -46},
#  1910: {'high': -34, 'low': -65, 'avg': -42},
#  1911: {'high': -17, 'low': -62, 'avg': -42},
#  1912: {'high': -11, 'low': -56, 'avg': -35},
#  1913: {'high': -2, 'low': -47, 'avg': -34},
#  1914: {'high': 5, 'low': -28, 'avg': -15},
#  1915: {'high': 7, 'low': -24, 'avg': -12},
#  1916: {'high': -8, 'low': -79, 'avg': -32},
#  1917: {'high': -17, 'low': -66, 'avg': -44},
#  1918: {'high': -4, 'low': -45, 'avg': -28},
#  1919: {'high': -12, 'low': -40, 'avg': -26},
#  1920: {'high': -7, 'low': -42, 'avg': -25},
#  1921: {'high': -1, 'low': -29, 'avg': -17},
#  1922: {'high': -12, 'low': -43, 'avg': -27},
#  1923: {'high': 2, 'low': -39, 'avg': -24},
#  1924: {'high': -6, 'low': -40, 'avg': -25},
#  1925: {'high': 9, 'low': -37, 'avg': -20},
#  1926: {'high': 20, 'low': -27, 'avg': -9},
#  1927: {'high': 0, 'low': -36, 'avg': -20},
#  1928: {'high': 0, 'low': -36, 'avg': -18},
#  1929: {'high': -11, 'low': -59, 'avg': -34},
#  1930: {'high': 17, 'low': -29, 'avg': -14},
#  1931: {'high': 3, 'low': -23, 'avg': -9},
#  1932: {'high': 15, 'low': -29, 'avg': -16},
#  1933: {'high': -21, 'low': -45, 'avg': -29},
#  1934: {'high': 4, 'low': -32, 'avg': -13},
#  1935: {'high': 15, 'low': -35, 'avg': -20},
#  1936: {'high': -3, 'low': -38, 'avg': -16},
#  1937: {'high': 11, 'low': -18, 'avg': -4},
#  1938: {'high': 11, 'low': -22, 'avg': -3},
#  1939: {'high': 44, 'low': -19, 'avg': -3},
#  1940: {'high': 28, 'low': -5, 'avg': 12},
#  1941: {'high': 33, 'low': 2, 'avg': 18},
#  1942: {'high': 26, 'low': -4, 'avg': 6},
#  1943: {'high': 25, 'low': -8, 'avg': 8},
#  1944: {'high': 35, 'low': 3, 'avg': 21},
#  1945: {'high': 27, 'low': -8, 'avg': 9},
#  1946: {'high': 15, 'low': -35, 'avg': -7},
#  1947: {'high': 8, 'low': -16, 'avg': -4},
#  1948: {'high': 7, 'low': -25, 'avg': -10},
#  1949: {'high': 10, 'low': -23, 'avg': -10},
#  1950: {'high': -3, 'low': -38, 'avg': -18},
#  1951: {'high': 14, 'low': -43, 'avg': -7},
#  1952: {'high': 12, 'low': -14, 'avg': 1},
#  1953: {'high': 18, 'low': -6, 'avg': 7},
#  1954: {'high': 6, 'low': -28, 'avg': -15},
#  1955: {'high': 14, 'low': -35, 'avg': -15},
#  1956: {'high': -8, 'low': -31, 'avg': -20},
#  1957: {'high': 16, 'low': -11, 'avg': 4},
#  1958: {'high': 39, 'low': -8, 'avg': 7},
#  1959: {'high': 18, 'low': -9, 'avg': 3},
#  1960: {'high': 18, 'low': -34, 'avg': -2},
#  1961: {'high': 19, 'low': -15, 'avg': 6},
#  1962: {'high': 14, 'low': -4, 'avg': 4},
#  1963: {'high': 27, 'low': -14, 'avg': 7},
#  1964: {'high': -2, 'low': -31, 'avg': -20},
#  1965: {'high': -3, 'low': -19, 'avg': -10},
#  1966: {'high': 9, 'low': -17, 'avg': -5},
#  1967: {'high': 15, 'low': -21, 'avg': -2},
#  1968: {'high': 21, 'low': -25, 'avg': -7},
#  1969: {'high': 28, 'low': -14, 'avg': 7},
#  1970: {'high': 22, 'low': -12, 'avg': 3},
#  1971: {'high': -2, 'low': -19, 'avg': -9},
#  1972: {'high': 19, 'low': -24, 'avg': 1},
#  1973: {'high': 31, 'low': -6, 'avg': 16},
#  1974: {'high': 11, 'low': -29, 'avg': -8},
#  1975: {'high': 16, 'low': -19, 'avg': -2},
#  1976: {'high': 10, 'low': -26, 'avg': -11},
#  1977: {'high': 30, 'low': 0, 'avg': 17},
#  1978: {'high': 21, 'low': -17, 'avg': 6},
#  1979: {'high': 47, 'low': -10, 'avg': 16},
#  1980: {'high': 43, 'low': 17, 'avg': 27},
#  1981: {'high': 55, 'low': 14, 'avg': 33},
#  1982: {'high': 43, 'low': -1, 'avg': 13},
#  1983: {'high': 52, 'low': 16, 'avg': 31},
#  1984: {'high': 33, 'low': -5, 'avg': 16},
#  1985: {'high': 22, 'low': -7, 'avg': 12},
#  1986: {'high': 39, 'low': 0, 'avg': 18},
#  1987: {'high': 47, 'low': 16, 'avg': 33},
#  1988: {'high': 57, 'low': 12, 'avg': 41},
#  1989: {'high': 38, 'low': 14, 'avg': 29},
#  1990: {'high': 76, 'low': 29, 'avg': 44},
#  1991: {'high': 53, 'low': 30, 'avg': 41},
#  1992: {'high': 47, 'low': 0, 'avg': 22},
#  1993: {'high': 38, 'low': 6, 'avg': 24},
#  1994: {'high': 46, 'low': 2, 'avg': 31},
#  1995: {'high': 78, 'low': 26, 'avg': 45},
#  1996: {'high': 49, 'low': 19, 'avg': 34},
#  1997: {'high': 65, 'low': 32, 'avg': 47},
#  1998: {'high': 90, 'low': 42, 'avg': 62},
#  1999: {'high': 66, 'low': 31, 'avg': 40},
#  2000: {'high': 58, 'low': 24, 'avg': 41},
#  2001: {'high': 70, 'low': 43, 'avg': 54},
#  2002: {'high': 90, 'low': 44, 'avg': 63},
#  2003: {'high': 75, 'low': 48, 'avg': 62},
#  2004: {'high': 73, 'low': 24, 'avg': 54},
#  2005: {'high': 76, 'low': 57, 'avg': 67},
#  2006: {'high': 74, 'low': 47, 'avg': 62},
#  2007: {'high': 95, 'low': 47, 'avg': 64},
#  2008: {'high': 73, 'low': 23, 'avg': 52},
#  2009: {'high': 76, 'low': 51, 'avg': 64},
#  2010: {'high': 92, 'low': 47, 'avg': 70},
#  2011: {'high': 72, 'low': 49, 'avg': 58},
#  2012: {'high': 75, 'low': 45, 'avg': 62},
#  2013: {'high': 79, 'low': 53, 'avg': 65},
#  2014: {'high': 88, 'low': 52, 'avg': 74},
#  2015: {'high': 111, 'low': 71, 'avg': 87},
#  2016: {'high': 135, 'low': 78, 'avg': 99},
#  2017: {'high': 113, 'low': 70, 'avg': 90},
#  2018: {'high': 91, 'low': 75, 'avg': 81}}

# %% [markdown]
# ## Temp Statistics Visualization

# %%
import matplotlib.pyplot as plt
import numpy as np



years = [int(year) for year in list(temp_stats.keys())]
averages = [temp_stats.get(year).get('avg') for year in years]
highs = [temp_stats.get(year).get('high') for year in years]
lows = [temp_stats.get(year).get('low') for year in years]

plt.figure(figsize=(15, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.xticks(rotation=90)
plt.plot(years, averages, color='red')
plt.xlabel("Year")
plt.ylabel("Land-Ocean Temperature in 0.01 degrees Celsius Difference from 1951-1980 Average")
plt.xticks(np.arange(min(years), max(years)+1, 5))
plt.grid()
plt.show()
#plt.plot(years, highs, color='black')
#plt.plot(years, lows, color='blue')

# %% [markdown]
# ## Visualize CO2 Data

# %%
years_co2 = list(co2_dict.keys())
total_co2 = [co2_dict.get(year).get('Total') for year in years_co2]
gas_co2 = [co2_dict.get(year).get('Gas') for year in years_co2]
liquid_co2 = [co2_dict.get(year).get('Liquids') for year in years_co2]
solid_co2 = [co2_dict.get(year).get('Solids') for year in years_co2]


plt.figure(figsize=(15, 8), dpi= 80, facecolor='w', edgecolor='k')
plt.xticks(rotation=90)

plt.plot(years_co2, total_co2, color='blue', label="Total CO2")
plt.plot(years_co2, gas_co2, color='green', label="Gaseous CO2")
plt.plot(years_co2, solid_co2, color='red', label="Solid CO2")
plt.plot(years_co2, liquid_co2, color='purple', label="Liquid CO2")

plt.xlabel("Year")
plt.ylabel("CO2 Emissions in million metric tons")
plt.xticks(np.arange(min(years_co2), max(years_co2)+1, 10))
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ## Visuzalize Correlation between CO2 emissions and Temperature Change

# %%
fig, ax1 = plt.subplots()

## Truncate both Data sets so that the years of recorded values overlap
## CO2 Data: 1750 - 2013
## Temp Data: 1880 - 2018
## Overlapping years: 1880-2013


plt.title("CO2 Emission and Temperature Change Correlation")

ax1.set_xlabel("Year")
ax1.set_ylabel("Land-Ocean Temperature in 0.01 degrees Celsius Difference from 1951-1980 Average")
ax1.plot(years, averages, color="red", label="Temp Change")
ax1.tick_params(axis="y", labelcolor="red")

ax2 = ax1.twinx()
ax2.set_ylabel("CO2 Emissions in million metric tons")
ax2.plot(years_co2, total_co2, color="blue", label="Total CO2 Emissions")
ax2.tick_params(axis='y', labelcolor="blue")

fig.set_figheight(8)
fig.set_figwidth(15)
fig.legend(loc=2)
plt.show()
